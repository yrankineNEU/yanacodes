# %% [markdown]
# <a href="https://colab.research.google.com/github/yrankineNEU/yanacodes/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Import data set
dataset = pd.read_csv('cancer.csv')

# %%
# Map correlations between diagnosis and features to predict diagnosis

# x is equal to everything in data set except for diagnosis column
x = dataset.drop(columns=["diagnosis(1=m, 0=b)"])

# %%
y = dataset["diagnosis(1=m, 0=b)"]

# %%
from sklearn.model_selection import train_test_split

# 20% of data is split to testing set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
import tensorflow as tf

model = tf.keras.models.Sequential()

# %%
# Create neural network with output of 256 neurons
model.add(tf.keras.layers.Dense(256, input_shape=x_train.shape[1:], activation='sigmoid'))
model.add(tf.keras.layers.Dense(256, activation='sigmoid'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7203 - loss: 0.5942
# Epoch 2/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7824 - loss: 0.4295
# Epoch 3/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8892 - loss: 0.2853
# Epoch 4/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9028 - loss: 0.2380
# Epoch 5/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9116 - loss: 0.2428
# Epoch 6/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9173 - loss: 0.2036
# Epoch 7/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9187 - loss: 0.2059
# Epoch 8/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9228 - loss: 0.2142
# Epoch 9/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9368 - loss: 0.2063
# Epoch 10/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9285 - loss: 0.1948
# Epoch 11/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9257 - loss: 0.2054
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9502 - loss: 0.0936
# [0.09775927662849426, 0.9561403393745422]
